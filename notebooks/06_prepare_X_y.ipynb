# %% [markdown]
# ## Model Objective
#
# We want to predict if a passenger would survived to the Titanic using only the available information before knowing the result.
#
# **Target:** survived
#
# **Features:** sex, age, pclass, fare, sibsp, parch, embarked...

# %%
# Load the cleaned dataset from notebook 04
import pandas as pd

df_clean = pd.read_csv("../data/titanic_clean.csv")
print("Dataset loaded successfully!")
print(f"Dataset shape: {df_clean.shape}")
df_clean.head()
# Out:
# Dataset loaded successfully!
# Dataset shape: (891, 9)
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  alone
# 0         0       3    1  22.0      1      0   7.2500         2      0
# 1         1       1    1  38.0      1      0  71.2833         0      0
# 2         1       3    1  26.0      0      0   7.9250         2      1
# 3         1       1    1  35.0      1      0  53.1000         2      0
# 4         0       3    1  35.0      0      0   8.0500         2      1

# %%
df_clean.columns #Show the column names of the DataFrame
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'alone'],
#       dtype='str')

# %%
y = df_clean["survived"] #Target variable
print(y.head()) #Show the first 5 rows of the target variable
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
X = df_clean.drop(columns=["survived"]) #Features variable, delete the 'survived' column from the DataFrame to create the features variable
print(X.head()) #Show the first 5 rows of the features variable
# Out:
#    pclass  sex   age  sibsp  parch     fare  embarked  alone
# 0       3  0.0  22.0      1      0   7.2500         2      0
# 1       1  1.0  38.0      1      0  71.2833         0      0
# 2       3  1.0  26.0      0      0   7.9250         2      1
# 3       1  1.0  35.0      1      0  53.1000         2      0
# 4       3  0.0  35.0      0      0   8.0500         2      1

# %%
print(X.shape)
print(y.shape)
# Out:
# (891, 8)
# (891,)

# %%
X.columns
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'alone'], dtype='str')
