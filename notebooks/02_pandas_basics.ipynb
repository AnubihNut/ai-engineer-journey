# %%
import pandas as pd

datos = {
    "Nombre": ["Ana", "Luis", "Marta"],
    "Edad": [24, 31, 27],
    "Ciudad": ["Madrid", "Sevilla", "Valencia"]
}

df = pd.DataFrame(datos)

print("DataFrame completo:")
df
print("\nPrimeras 3 filas:")
df.head(2)
print("\nÚltimas 2 filas:")
df.tail(2)
#Show the shape of the DataFrame (number of rows and columns)
df.shape
#Show the column names of the DataFrame
df.columns
#Show the data types of each column in the DataFrame
df.dtypes

df.describe()
#Show the summary statistics of the numerical columns in the DataFrame
df.info()

datos1 = {
    "Producto" : ["Ratón", "Teclado", "Monitor"],
    "Precio" : [25,80,230],
    "Stock": [12,5,8]
}

frame = pd.DataFrame(datos1)
frame.head(1)
frame
frame.shape
frame.describe()
# Out:
# DataFrame completo:
#
# Primeras 3 filas:
#
# Últimas 2 filas:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nombre  3 non-null      str
#  1   Edad    3 non-null      int64
#  2   Ciudad  3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
#            Precio      Stock
# count    3.000000   3.000000
# mean   111.666667   8.333333
# std    106.105294   3.511885
# min     25.000000   5.000000
# 25%     52.500000   6.500000
# 50%     80.000000   8.000000
# 75%    155.000000  10.000000
# max    230.000000  12.000000
