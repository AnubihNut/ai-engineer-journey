# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression() #Here we are creating an instance of the LinearRegression class from the sklearn.linear_model module. This instance will be used to fit a linear regression model to our data.

print(type(modelo))
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>

# %%
dir(modelo) #just to see the methods and attributes of the LinearRegression class. This will give us an idea of what we can do with this instance, such as fitting the model, making predictions, and accessing model parameters.
# Out:
# ['__abstractmethods__',
#  '__annotate_func__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_get_class_level_metadata_request_values',
#  '_get_doc_link',
#  '_get_fitted_attr_html',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params_html',
#  '_html_repr',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
# ...
